# %%
import numpy as np
import os.path
import csv
import glob
import h5py as h5py
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
import cv2
from keras.models import Model

# %%
# Initialize the ResNet-50 model
base_model = ResNet50(weights='imagenet', include_top=True)

def extractor(image_path):
    model = Model(inputs=base_model.input, outputs=base_model.layers[-2].output)
    #print(model.summary())

    img = cv2.imread(image_path)  # Read image using OpenCV
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
    img = cv2.resize(img, (224, 224))  # Resize to match ResNet-50 input size
    img = preprocess_input(img)  # Preprocess input for ResNet-50
    features = model.predict(np.expand_dims(img, axis=0))
    print(features.shape)
    return features.flatten()  # Return extracted features

# %%
def extract_features():
	with open('data/data_new.csv','r') as f:
		reader = csv.reader(f)
		for videos in reader:
			path = os.path.join('data', 'new_sequences', videos[2] + '-' + str(26) + \
'-features.npy')
		
			path_frames = os.path.join('data', videos[0], videos[1])
			filename = videos[2]
			frames = sorted(glob.glob(os.path.join(path_frames, filename + '/*png')))
		
			sequence = []
			for image in frames:
				
				features = extractor(image)
				print ('Appending sequence of image:',image,' of the video:',videos[2])			
								
				sequence.append(features)
				print(features.shape)
                
			np.save(path,sequence)
			print ('Sequences saved successfully')

# %%
# Initialize the ResNet-50 model (excluding top classification layers)
base_model = ResNet50(weights='imagenet', include_top=True)

def extractor(image_path):
    model = Model(inputs=base_model.input, outputs=base_model.layers[-2].output)
    #print(model.summary())

    img = cv2.imread(image_path)  # Read image using OpenCV
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
    img = cv2.resize(img, (224, 224))  # Resize to match ResNet-50 input size
    img = preprocess_input(img)  # Preprocess input for ResNet-50
    features = model.predict(np.expand_dims(img, axis=0))
    print(features.shape)
    return features.flatten()  # Return extracted features

# %%
extract_features()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0001.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0002.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0003.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0004.png  of the video: Drowsy_Video13
# (2048,)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x3188f08b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0005.png  of the video: Drowsy_Video13
# (2048,)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x31588a8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0006.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0007.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0008.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0009.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0010.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0011.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0012.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0013.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0014.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0015.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0016.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0017.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0018.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0019.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0020.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0021.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0022.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0023.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0024.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0025.png  of the video: Drowsy_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video13/V0026.png  of the video: Drowsy_Video13
# (2048,)
# Sequences saved successfully
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 997ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0007.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0008.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0009.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0010.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0011.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0012.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0013.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0014.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0015.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 959ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0016.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0017.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0018.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0019.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0020.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0021.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0022.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0023.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0024.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0025.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0026.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0027.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0028.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0029.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0030.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0031.png  of the video: Drowsy_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video14/ZA0032.png  of the video: Drowsy_Video14
# (2048,)
# Sequences saved successfully
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0001.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0002.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0003.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0004.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0005.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0006.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0007.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0008.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0009.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0010.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0011.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0012.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0013.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0014.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0015.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0016.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0017.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0018.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0019.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0020.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0021.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0022.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0023.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0024.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0025.png  of the video: Drowsy_Video15
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# (1, 2048)
# Appending sequence of image: data/training/Drowsy/Drowsy_Video15/ZB0026.png  of the video: Drowsy_Video15
# (2048,)
# Sequences saved successfully
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0001.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0002.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0004.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0005.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0006.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0007.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0008.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0012.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0013.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0014.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0015.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0016.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0017.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0018.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0019.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0020.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0021.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0022.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0023.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0024.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0025.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0026.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0027.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0028.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0029.png  of the video: Alert_Video13
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video13/v0030.png  of the video: Alert_Video13
# (2048,)
# Sequences saved successfully
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0001.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0002.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0003.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0004.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0005.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0006.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0007.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0008.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0009.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0010.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0011.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0012.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0013.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0014.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0015.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0016.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0017.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0018.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0019.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0020.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0021.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0022.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0023.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0024.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_Video14/za0025.png  of the video: Alert_Video14
# (2048,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# (1, 2048)
# Appending sequence of image: data/training/Alert/Alert_